# %%
import pandas as pd
data_1 = pd.read_csv("/home/komlan/Downloads/FD_EEC_2019.csv", sep=";")
data_1
# Out:
#         ANNEE  TRIM  CATAU2010R  METRODOM  TYPMEN7  AGE3  AGE5  COURED  \
# 0        2019     1           1         1        1    50    60       2
# 1        2019     2           1         1        3    50    60       1
# 2        2019     2           1         1        3    50    60       1
# 3        2019     3           1         1        3    50    60       1
# 4        2019     3           1         1        3    50    60       1
# ...       ...   ...         ...       ...      ...   ...   ...     ...
# 416293   2019     2           1         2        1    50    60       2
# 416294   2019     3           1         2        1    50    60       2
# 416295   2019     1           1         2        1    50    60       2
# 416296   2019     2           1         2        1    50    60       2
# 416297   2019     3           1         2        1    50    60       2
#
#         ENFRED  NFRRED  ...  DIP11  CSTOTPRM  IDENTM     EXTRIAN  EMPNBH  \
# ...

# %%
data_1.describe()
# Out:
#           ANNEE           TRIM     CATAU2010R       METRODOM        TYPMEN7  \
# count  416298.0  416298.000000  416298.000000  416298.000000  416298.000000
# mean     2019.0       2.483089       1.326002       1.107123       3.099092
# std         0.0       1.121424       0.776979       0.309270       1.568679
# min      2019.0       1.000000       1.000000       1.000000       1.000000
# 25%      2019.0       1.000000       1.000000       1.000000       2.000000
# 50%      2019.0       2.000000       1.000000       1.000000       3.000000
# 75%      2019.0       3.000000       1.000000       1.000000       4.000000
# max      2019.0       4.000000       4.000000       2.000000       9.000000
#
#                 AGE3           AGE5         COURED         ENFRED  \
# count  416298.000000  416298.000000  416298.000000  416298.000000
# mean       37.750578      42.863670       1.415753       1.669765
# std        13.940921      16.814477       0.492852       0.470298
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416298 entries, 0 to 416297
# Columns: 124 entries, ANNEE to NBTOTE
# dtypes: float64(105), int64(13), object(6)
# memory usage: 393.8+ MB

# %%
list(data_1)
# Out:
# ['ANNEE',
#  'TRIM',
#  'CATAU2010R',
#  'METRODOM',
#  'TYPMEN7',
#  'AGE3',
#  'AGE5',
#  'COURED',
#  'ENFRED',
#  'NFRRED',
#  'SEXE',
#  'ACTEU',
#  'ACTEU6',
#  'ACTIF',
#  'ACTOP',
#  'AIDFAM',
#  'ANCCHOM',
#  'ANCINACT',
#  'CONTACT',
#  'CREACCP',
#  'DEM',
#  'DISPOC',
#  'GARDEB',
#  'HALOR',
#  'INSCONT',
#  'MRA',
#  'MRB',
#  'MRBBIS',
#  'MRC',
#  'MRD',
#  'MRDBIS',
#  'MRE',
#  'MREC',
#  'MRF',
#  'MRG',
#  'MRGBIS',
#  'MRH',
#  'MRI',
#  'MRJ',
#  'MRK',
#  'MRL',
#  'MRM',
#  'MRN',
#  'MRO',
#  'MRPASSA',
#  'MRPASSB',
#  'MRPASSC',
#  'MRS',
#  'NONDIC',
#  'NREC',
#  'NRECA',
#  'NRECB',
#  'OCCREF',
#  'OFFICC',
#  'OFFRE',
#  'PASTRA',
#  'PASTRB',
#  'PASTRF',
#  'PERCREV',
#  'RABS',
#  'RAISNREC',
#  'RAISNSOU',
#  'RAISPAS',
#  'SOU',
#  'SOUA',
#  'SOUB',
#  'SOUC',
#  'SOUSEMPL',
#  'STCHE',
#  'TEMP',
#  'TRAREF',
#  'TYPCONT',
#  'TYPCONTB',
#  'CHPUB',
#  'CSE',
#  'CSER',
#  'CSP',
#  'CSTOT',
#  'CSTOTR',
#  'FONCTC',
#  'NAFG004UN',
# ...

# %%
data_2 = pd.read_csv("/home/komlan/Downloads/Varmod_EEC_2019.csv", sep=";")
data_2
# Out:
#      COD_VAR                                            LIB_VAR COD_MOD  \
# 0      ANNEE                    Année de référence de l'enquête    2019
# 1       TRIM                Trimestre de référence de l'enquête       1
# 2       TRIM                Trimestre de référence de l'enquête       2
# 3       TRIM                Trimestre de référence de l'enquête       3
# 4       TRIM                Trimestre de référence de l'enquête       4
# ...      ...                                                ...     ...
# 1872  NBTOTE  Nombre d'heures travaillées en moyenne par sem...    97.5
# 1873  NBTOTE  Nombre d'heures travaillées en moyenne par sem...      98
# 1874  NBTOTE  Nombre d'heures travaillées en moyenne par sem...    98.5
# 1875  NBTOTE  Nombre d'heures travaillées en moyenne par sem...      99
# 1876  NBTOTE  Nombre d'heures travaillées en moyenne par sem...    99.5
#
#                                  LIB_MOD TYPE_VAR  LONG_VAR
# ...
